# %%
pip install pandas numpy matplotlib seaborn nltk textblob wordcloud
# Out:
# Requirement already satisfied: pandas in /home/rohan/jupyter_env/lib64/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /home/rohan/jupyter_env/lib64/python3.13/site-packages (2.3.5)
# Requirement already satisfied: matplotlib in /home/rohan/jupyter_env/lib64/python3.13/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /home/rohan/jupyter_env/lib64/python3.13/site-packages (0.13.2)
# Requirement already satisfied: nltk in /home/rohan/jupyter_env/lib64/python3.13/site-packages (3.9.4)
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: click in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from nltk) (2026.3.32)
# Requirement already satisfied: tqdm in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from nltk) (4.67.3)
# Requirement already satisfied: six>=1.5 in /home/rohan/jupyter_env/lib64/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.0/625.0 kB 7.6 MB/s  0:00:00
# Downloading wordcloud-1.9.6-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (550 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 550.7/550.7 kB 18.0 MB/s  0:00:00
# Installing collected packages: textblob, wordcloud
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [wordcloud]
# Successfully installed textblob-0.20.0 wordcloud-1.9.6
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
from textblob import TextBlob
from wordcloud import WordCloud
